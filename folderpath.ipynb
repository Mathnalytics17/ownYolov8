# %%
import os

def imprimir_estructura(directorio):
    for ruta_directorio, subdirectorios, archivos in os.walk(directorio):
        nivel = ruta_directorio.replace(directorio, '').count(os.sep)
        indentacion = ' ' * 4 * nivel
        print(f'{indentacion}{os.path.basename(ruta_directorio)}/')
        sub_indentacion = ' ' * 4 * (nivel + 1)
        for archivo in archivos:
            print(f'{sub_indentacion}{archivo}')

# Llama a la función con el directorio que quieras mostrar
imprimir_estructura(r'C:\Users\ASUS RYZEN 7\Documents\PROYECTOS\OwnYolo')
# Out:
# OwnYolo/
#     folderpath.ipynb
#     main.py
#     modelclass.py
#     data/
#         annotator.py
#         augment.py
#         base.py
#         build.py
#         converter.py
#         dataset.py
#         loaders.py
#         split_dota.py
#         utils.py
#         __init__.py
#         explorer/
#             explorer.py
#             utils.py
#             __init__.py
#             gui/
#                 dash.py
#                 __init__.py
#         scripts/
#             download_weights.sh
#             get_coco.sh
#             get_coco128.sh
#             get_imagenet.sh
#     detect/
#         predict.py
#         train.py
#         val.py
#         __init__.py
#     engine/
#         exporter.py
#         model.py
#         predictor.py
#         results.py
#         trainer.py
#         tuner.py
#         validator.py
#         __init__.py
#     models/
#         yoloclsv8.py
#     nn/
#         task.py
#     utils/
#         args.yaml
#         autobatch.py
# ...
